# %% [markdown]
# ## Introduction

# %% [markdown]
# Trigger questions for the exploratory data analysis:
#
# 1. How many hotels do we have in the dataset?
# 2. From which countries are the reviewed hotels?
# 3. How many reviews does each hotel have?
# 4. What percentage of reviews have a score higher than 5?
# 5. Which kinds of guests are there?
# 6. Where are reviewers from? Is there any nation-specific behaviour?
# 7. What information do we have regarding dates?
# 8. Which hotel would you recommend to a couple on vacation?

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Import libraries and dataset

# %%
# Importing required libraries.
import pandas as pd
import numpy as np
import seaborn as sns #visualization
import matplotlib.pyplot as plt #visualization
# %matplotlib inline 
sns.set(color_codes=True)

# %%
# Import csv
df = pd.read_csv('hotel_reviews_enriched.csv')

# %% [markdown]
# ### Have a first look at the data

# %% [markdown]
# What columns do we have?

# %% [markdown]
# How many reviews do we have in total?

# %% [markdown]
# What datatypes do we have?

# %% [markdown]
# ### Check for inconsistencies

# %% [markdown]
# Are there any duplicates?

# %%
df_clean =

# %% [markdown]
# And null values?

# %%
df_clean =

# %% [markdown]
# ## Data analysis

# %% [markdown]
# ### 1. How many hotels do we have in the dataset?

# %%
n_hotels = 
print(f"On the dataset we have reviews from {n_hotels} hotels")

# %% [markdown]
# ### 2. From which countries are the reviewed hotels?

# %%
hotels_by_country =

# %%
# Try plotting their distribution

# %% [markdown]
# ### 3. How many reviews does each hotel have?

# %%
# Group the hotels by name and count how many reviews each one has
reviews_by_hotel =

# %%
# Rename the column to `reviews_by_hotel`

# %%
# Add the `reviews_by_hotel` column to `df` by merging both DataFrames by hotel name
df =

# %%
# Check if the merge worked

# %% [markdown]
# ### 4. What percentage of reviews have a score higher than 5?

# %%
# Create a histogram plot of the Reviwer_Score column

# %%
# Add a boolean column to the DataFrame that indicates whether the review score is greater than 5

# %%
# How many reviews were greater than 5?
# Print and plot the results

# %%
# Calculate and print the percentages

# %% [markdown]
# ### 5. Which kinds of guests are there?

# %%
# Plot number of reviews by guest type

# %% [markdown]
# ### 6. Where are reviewers from? Is there any nation-specific behaviour?

# %%
# Create a DataFrame that contains Reviewer Nationality and 
# how many reviews does the dataset contain for each of them.
reviews_by_nationality =

# %%
reviews_by_nationality["size"].describe()

# %%
# Order the DataFrame by `size` and get the top 5 nationalities
top_nationality_reviewers =

# %%
top_nationality_reviewers

# %%
# Plot number of reviews for the top 5 nationalities

# %% [markdown]
# We want to plot the reviewer scores for each of the top nationalities

# %%
# Build a Series with the top nationalities names
list_top_nationalities =

# %%
# Create a subset of `df` with only the reviews from the top nationalities
df_smaller =

# %%
# Create a boxplot that shows for each reviewer nationality the distribution of reviewer scores

# %%
# Create a DataFrame with 3 columns: Nationality, Score, review counts.
# review count being how many pairs of (Nationality, score) are there.

# %%
df_plot = df_plot.reset_index()
df_plot

# %%
# Plot a line plot that illustrates the three columns

# %%
# Find the different review tendencies for each nationality and guest type

# %% [markdown]
# ### 7. What information do we have regarding date?

# %%
# What do we have in the "Review_date" column?

# %%
# Try to format it to datetime objects
df['Review_Date'] =

# %%
# How is the review tendency of our dataset?

# %%
# How many reviews do we have for:
# - Day of year
# - Day of week
# - Week of year

# %% [markdown]
# ### 8. Which hotel would you recommend to a couple on vacation? (Simplest approach)

# %%
# Get the value counts for the guest types

# %%
# Plot a FacetGrid for each guest Type with the reviewer score distribution

# %%
# Lets find how many reviews we have for each hotel that hosted couples

# %%
# Which are the hotels for couples with more than 100 reviews?
hotel_names =

# %%
# Get the filtered dataset of hotels

# %%
# Get the max value and corresponding hotel, for avg score
best_hotel = 
best_score = 
print(f'Hotel: {best_hotel}')
print(f'Avg score: {best_score}')
